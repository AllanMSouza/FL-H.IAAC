# %%
import pickle
import pandas as pd
import numpy as np

# %%
for user in range(1, 25):
    with open(f'data/motion_sense/{user}_train.pickle', 'rb') as train_file:
        train = pickle.load(train_file)
        
    with open(f'data/motion_sense/{user}_test.pickle', 'rb') as test_file:
        test = pickle.load(test_file)
        
    y_train = train['activity'].values
    train.drop('activity', axis=1, inplace=True)
    x_train = train.values
    
    y_test = test['activity'].values
    test.drop('activity', axis=1, inplace=True)
    x_test = test.values
    
    return x_train, y_train, x_test, y_test

# %%
# Out:
#        accel_x   accel_y   accel_z  accel_norm    gyro_x    gyro_y    gyro_z  \
# time
# 0    -0.148693 -0.877139  1.031059   -1.148984  2.048487 -0.686301  0.831522
# 1    -0.366751 -0.985366  0.955829   -1.239544  2.473775 -1.558166  1.161859
# 2    -1.085514 -0.812943  1.113725   -0.746284  3.186029 -1.501653  1.800298
# 3    -1.208990 -0.394622  1.226513   -0.364281  3.160914 -1.499902  2.817946
# 4    -1.365409  0.266564  1.493114    0.374573  2.523259 -1.863126  2.774510
# ...        ...       ...       ...         ...       ...       ...       ...
# 4071 -0.240177 -0.017233  0.848565   -0.470746  2.100893  0.436585  1.593705
# 4072 -0.837711  1.646840  2.637658    2.157478  1.700459 -0.544008  3.127289
# 4073 -6.386752  4.554243  3.995935    7.374151 -1.458309 -0.761605  0.103389
# 4074 -3.996542  0.950658  1.573988    2.331043  0.222414  0.881159 -2.337278
# 4075 -1.625939 -0.547577  0.766457   -0.440846  0.284100  0.971665 -1.830444
#
#       subject  activity  trial
# time
# ...

# %%
for user in range(1, 31):
    with open(f'data/UCI-HAR/{user}_train.pickle', 'rb') as train_file:
        train = pickle.load(train_file)
        
    with open(f'data/UCI-HAR/{user}_test.pickle', 'rb') as test_file:
        test = pickle.load(test_file)
        
    y_train = train['label'].values
    train.drop('label', axis=1, inplace=True)
    x_train = train.values
    
    y_test = test['label'].values
    test.drop('label', axis=1, inplace=True)
    x_test = test.values
    
#     return x_train, y_train, x_test, y_test

# %%
train
# Out:
#            0         1         2         3         4         5         6    \
# 7318  0.112349  0.012569 -0.111625  0.057619  0.188972 -0.242086 -0.045303
# 7284  0.221696 -0.026658 -0.110730 -0.233621 -0.056805 -0.110279 -0.316443
# 7214  0.275425 -0.010566 -0.110626 -0.993018 -0.974590 -0.986407 -0.993596
# 7234  0.269968 -0.018963 -0.104345 -0.993132 -0.992986 -0.987742 -0.994579
# 7007  0.283560 -0.017872 -0.114945 -0.998933 -0.997677 -0.995308 -0.999232
# ...        ...       ...       ...       ...       ...       ...       ...
# 7346  0.237966 -0.001088 -0.148326 -0.218949 -0.012927  0.170019 -0.309599
# 6971  0.280223 -0.015785 -0.110003 -0.995720 -0.982407 -0.982917 -0.996391
# 6978  0.271844 -0.039139  0.024038 -0.969269 -0.778815 -0.773383 -0.980213
# 7140  0.289552  0.013567 -0.211645 -0.443779 -0.105946 -0.045845 -0.506603
# 7090  0.273962 -0.026303 -0.138232 -0.424739 -0.239636 -0.175271 -0.473906
#
# ...

# %%
y_train
# Out:
# array([3, 1, 4, 6, 4, 5, 6, 3, 6, 5, 6, 2, 5, 2, 6, 6, 2, 6, 5, 2, 2, 5,
#        6, 6, 5, 6, 4, 2, 6, 3, 5, 5, 3, 4, 6, 6, 6, 5, 5, 6, 6, 5, 6, 4,
#        6, 6, 6, 2, 2, 1, 4, 6, 4, 3, 2, 1, 3, 4, 1, 1, 5, 1, 5, 1, 4, 2,
#        5, 4, 5, 6, 6, 4, 3, 3, 3, 6, 5, 5, 4, 2, 1, 4, 5, 5, 1, 1, 6, 4,
#        2, 6, 2, 3, 2, 6, 2, 4, 5, 5, 2, 6, 6, 3, 4, 6, 2, 4, 3, 3, 4, 4,
#        1, 6, 4, 5, 5, 2, 4, 2, 3, 1, 3, 6, 3, 3, 4, 5, 2, 4, 3, 4, 2, 5,
#        5, 1, 1, 6, 1, 5, 3, 1, 2, 2, 6, 4, 6, 3, 3, 4, 2, 4, 5, 2, 4, 1,
#        4, 1, 2, 4, 1, 1, 2, 5, 5, 4, 1, 1, 2, 5, 1, 2, 2, 1, 5, 1, 4, 1,
#        2, 2, 5, 1, 1, 2, 1, 4, 3, 5, 5, 4, 3, 4, 3, 5, 6, 2, 2, 6, 1, 4,
#        6, 4, 1, 6, 3, 3, 5, 4, 3, 6, 1, 4, 2, 1, 2, 2, 3, 6, 3, 3, 2, 6,
#        3, 4, 5, 6, 2, 2, 6, 6, 1, 2, 6, 6, 2, 1, 3, 1, 5, 1, 5, 3, 1, 1,
#        4, 6, 3, 5, 6, 5, 1, 4, 6, 6, 2, 3, 6, 4, 3, 4, 5, 4, 3, 3, 6, 1,
#        4, 6, 1, 1, 2, 4, 2, 1, 2, 2, 6, 3, 3, 3, 6, 4, 5, 3, 2, 4, 1, 1,
# ...

# %%
y_t
