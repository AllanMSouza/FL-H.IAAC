# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plot_utils import *

# %% [markdown]
# # Average Accuracy

# %%
plot_server('Communication Round', 'Accuracy (%)')

# %% [markdown]
# # CPU time per Communication Round

# %%
plot_train('total_time', 'sum', 'Communication Round', 'CPU time (s)')

# %% [markdown]
# # Bytes Tx per Communication Round

# %%
plot_train('parameters', 'sum', 'Communication Round', 'Bytes Transmitted (Tx bytes)')

# %% [markdown]
# # Average Training Loss per Communication Round

# %%
plot_train('loss', 'mean', 'Communication Round', 'Training Loss')

# %% [markdown]
# # Average Training Accuracy per Communication Round

# %%
plot_train('acc', 'mean', 'Communication Round', 'Training Accuracy (%)')

# %% [markdown]
# # Average Accuracy in Evaluation per Communication Round

# %%
plot_evaluation('acc', 'mean', 'Communication Round', 'Validation Accuracy (%)')

# %% [markdown]
# # CPU Time per Number of Clients

# %%
plot_metric_by_numberclients('total_time', 'Number of Clients (#)', 'CPU Time (s)')

# %% [markdown]
# # Bytes Transmitted per Number of Clients

# %%
plot_metric_by_numberclients('parameters', 'Number of Clients (#)', 'Bytes transmitted (Tx bytes)',)
