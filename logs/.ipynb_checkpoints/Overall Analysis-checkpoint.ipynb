# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plot_utils import *

# %%
plot_server()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 plot_server()
#
# File ~/PosDoc/FedLTA/logs/plot_utils.py:59, in plot_server()
#      57 for model in MODELS:
#      58     for clients in NCLIENTS:
# ---> 59         df = pd.read_csv(f'{sol}/{clients}/{model}/MNIST/server.csv',
#      60                          names=['round', 'avg_acc', 'top-3_acc', 'best_acc'])
#      62         idx_clients = NCLIENTS.index(clients)
#      63         idx_model   = MODELS.index(model)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
plot_train('total_time', 'sum')

# %%
plot_train('parameters', 'sum')

# %%
plot_train('loss', 'mean')

# %%
plot_train('acc', 'mean')

# %%
plot_train('total_time', 'sum')

# %%
plot_evaluation('acc', 'mean')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
# ----> 1 plot_evaluation('acc', 'mean')
#
# File ~/PosDoc/FedLTA/logs/plot_utils.py:6, in plot_evaluation(metric, estimator)
#       4 def plot_evaluation(metric, estimator):
#       5
# ----> 6     fig, ax = plt.subplots(nrows=NROWS, ncols=NCOLS, figsize=(25, 15))
#       7
#       8     for sol in SOLUTIONS:
#
# NameError: name 'plt' is not defined
